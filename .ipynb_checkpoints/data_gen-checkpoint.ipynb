# %% [markdown]
# # Extracts & cleans data from Spotify using spotipy API

# %%
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials

# credentials
OAUTH_TOKEN = 'BQB0yUZJc15geI7IIj11Wy81Pwk183hsfmYRQux0xT_vBbqP05JoAYnb1pYujRcBam24BwRB62RZ_9kXN5slSGr6RyNkrA8Zwul36QPdsQJJiU6sliX2CUFX0ueVSx8A1IIbzNrWxX0G_ELQ'
CLIENT_ID = '7ae4b76356ed4aafb51d7e944a4212c3'
CLIENT_SECRET = '170253260d12470a850506ce5d8c0b30'

# auth
auth_manager = SpotifyClientCredentials(client_id = CLIENT_ID, client_secret = CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
# fetches classical essentials playlist from spotify
ce_id = '37i9dQZF1DWWEJlAGA9gs0' # playlist id
ce_playlist = sp.playlist_tracks(ce_id)
total_tracks = ce_playlist['total']

# 100 item limit per request
while total_tracks != len(ce_playlist['items']):
    add = sp.playlist_tracks(ce_id, offset = len(ce_playlist['items']))
    ce_playlist['items'].extend(add['items'])

# %%
import pandas as pd

get_feature = lambda lst, feature: [lst[i][feature] for i in range(len(lst))] 

# refines a list of playlist items
def playlist_df(items: list) -> pd.DataFrame:
    track_count = len(items)
    tracks = get_feature(items,'track')
    artists = get_feature(tracks,'artists')
    
    artist_names = []
    for ix in range(track_count):
        z = []
        for jx in range(len(artists[ix])):
            z.append(artists[ix][jx]['name'])
        artist_names.append(z)
    
    return pd.DataFrame({
        'name': get_feature(tracks,'name'),
        'artist_name': artist_names,
        'id': get_feature(tracks,'id')
    })

# returns audio features given a list of track ids
def get_audio_features(ids: list) -> pd.DataFrame:
    audio_features = []
    total = len(ids)
    
    # 100 item limit per request
    for i in range(total//100):
        audio_features.extend(sp.audio_features(ids[i*100:i*100+100]))
    audio_features.extend(sp.audio_features(ids[len(audio_features):total]))
    
    # convert to pandas dataframe
    return pd.DataFrame({
        'danceability': get_feature(audio_features,'danceability'),
        'energy': get_feature(audio_features,'energy'),
        'key': get_feature(audio_features,'key'),
        'loudness': get_feature(audio_features,'loudness'),
        'mode': get_feature(audio_features,'mode'),
        'speechiness': get_feature(audio_features,'speechiness'),
        'acousticness': get_feature(audio_features,'acousticness'),
        'instrumentalness': get_feature(audio_features,'instrumentalness'),
        'liveness': get_feature(audio_features,'liveness'),
        'valence': get_feature(audio_features,'valence'),
        'tempo': get_feature(audio_features,'tempo')
    })

# %%
ce_df = playlist_df(ce_playlist['items'])
ce_af = get_audio_features(ce_df.id)
ce_df = ce_df.join(ce_af)

# %%
ce_df
# Out:
#                                                   name  \
# 0    The Well-Tempered Clavier: Book 1, BWV 846-869...
# 1                                   The Lark Ascending
# 2    Handel / Orch. Hale: Keyboard Suite in D Minor...
# 3     Bagatelle No. 25 in A Minor, "Für Elise", WoO 59
# 4    Rhapsody On A Theme Of Paganini, Op.43: Variat...
# ..                                                 ...
# 167  The Firebird (L'oiseau De Feu) - Suite (1919):...
# 168  Holberg Suite, Op. 40: 1. Präludium (Allegro v...
# 169                        Die Forelle, Op. 32, D. 550
# 170  Cello Concerto No. 1 in C Major, Hob.VIIb:1: I...
# 171                                 Lohengrin: Prelude
#
#                                            artist_name  \
# 0                   [Johann Sebastian Bach, Lang Lang]
# 1    [Ralph Vaughan Williams, Tasmin Little, BBC Ph...
# 2    [George Frideric Handel, Alexander Briger, Aca...
# 3                    [Ludwig van Beethoven, Lang Lang]
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# display a grid of colors 
def plot_colors(colors: list, grid: tuple):
    # assumed rows*cols == len(colors)
    rows, cols = grid
    fig, axs = plt.subplots(rows, cols)
    i = 0
    
    if rows == 1 or cols == 1: 
        imgs = cols if rows == 1 else rows
        for img in range(imgs):
            axs[img].imshow([[colors[i]]])
            axs[img].axis('off')
            i += 1
    else:
        for row in range(rows):
            for col in range(cols):
                axs[row,col].imshow([[colors[i]]])
                axs[row,col].axis('off')
                i += 1
            
    plt.show()

# %%
import numpy as np

red = lambda x : 255*0.5*np.sin(x) + 0.5*255
green = lambda x : 255*0.5*np.sin(x + np.pi/2)+0.5*255
blue = lambda x : 255*0.5*np.sin(x + np.pi)+0.5*255

# %%
import numpy as np

# grid using sinusoidal color definition w/ percentage based shading

red = lambda x : 255*0.5*np.sin(x) + 0.5*255
green = lambda x : 255*0.5*np.sin(x + np.pi/2)+0.5*255
blue = lambda x : 255*0.5*np.sin(x + np.pi)+0.5*255

row_count = 10
col_count = 13
colors = []
X = np.linspace(0,2*np.pi,num = col_count)

for row in range(1,row_count+1):
    p = 2/row_count*(row_count - row)
    for Xi in X:
        colors.append(np.clip(np.array([red(Xi), green(Xi), blue(Xi)])*p,0,255).astype(int))

plot_colors(colors,(row_count,col_count))

# %%
# preset color pallete with int based shading
colors_base = [[255,0,0],[255,128,0],[255,255,0] ]

# %%
colors
# Out:
# [[0, 0, 0],
#  [127, 0, 0],
#  [254, 0, 0],
#  [0, 127, 0],
#  [127, 127, 0],
#  [254, 127, 0],
#  [0, 254, 0],
#  [127, 254, 0],
#  [254, 254, 0],
#  [0, 0, 127],
#  [127, 0, 127],
#  [254, 0, 127],
#  [0, 127, 127],
#  [127, 127, 127],
#  [254, 127, 127],
#  [0, 254, 127],
#  [127, 254, 127],
#  [254, 254, 127],
#  [0, 0, 254],
#  [127, 0, 254],
#  [254, 0, 254],
#  [0, 127, 254],
#  [127, 127, 254],
#  [254, 127, 254],
#  [0, 254, 254],
#  [127, 254, 254],
#  [254, 254, 254]]
